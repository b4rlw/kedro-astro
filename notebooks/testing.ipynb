# %%
from pprint import pprint

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
# %load_ext kedro.ipython
# Out:
# [05/19/23 16:06:25] INFO     Resolved project path as: /Users/jordan/repos/kedro-astro.             ]8;id=930978;file:///Users/jordan/repos/kedro-astro/.env/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=561225;file:///Users/jordan/repos/kedro-astro/.env/lib/python3.10/site-packages/kedro/ipython/__init__.py#134\134]8;;\
#                              To set a different path, run '%reload_kedro <project_root>'
# [05/19/23 16:06:25] WARNING  /Users/jordan/repos/kedro-astro/.env/lib/python3.10/importlib/__init__ ]8;id=142464;file:///Users/jordan/repos/kedro-astro/.env/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=644596;file:///Users/jordan/repos/kedro-astro/.env/lib/python3.10/warnings.py#109\109]8;;\
#                              .py:126: DeprecationWarning: `kedro.extras.datasets` is deprecated and
#                              will be removed in Kedro 0.19, install `kedro-datasets` instead by
# ...

# %%
# %reload_ext kedro.ipython
# Out:
#                     INFO     Resolved project path as: /Users/jordan/repos/kedro-astro.             ]8;id=266631;file:///Users/jordan/repos/kedro-astro/.env/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=845975;file:///Users/jordan/repos/kedro-astro/.env/lib/python3.10/site-packages/kedro/ipython/__init__.py#134\134]8;;\
#                              To set a different path, run '%reload_kedro <project_root>'
# [05/19/23 16:06:26] INFO     Kedro project Kedro Astro                                              ]8;id=854471;file:///Users/jordan/repos/kedro-astro/.env/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=932725;file:///Users/jordan/repos/kedro-astro/.env/lib/python3.10/site-packages/kedro/ipython/__init__.py#103\103]8;;\
# ...

# %%
catalog.list()
# Out:
# ['dark_frame', 'sun_171', 'sun_195', 'sunpy_map', 'parameters']

# %%
dark_frame = catalog.load("dark_frame")
sun_171 = catalog.load("sun_171")
sun_195 = catalog.load("sun_195")
sunpy_map = catalog.load("sunpy_map")
# Out:
#                     INFO     Loading data from 'dark_frame' (FITSDataSet)...                    ]8;id=24834;file:///Users/jordan/repos/kedro-astro/.env/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=620971;file:///Users/jordan/repos/kedro-astro/.env/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\
#                     INFO     Loading data from 'sun_171' (FITSDataSet)...                       ]8;id=787672;file:///Users/jordan/repos/kedro-astro/.env/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=380369;file:///Users/jordan/repos/kedro-astro/.env/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\
# ...

# %%
def plot_fits(hdu):
    pprint(hdu.header)
    _, axes = plt.subplots(frameon=False)
    axes.imshow(hdu.data)
    axes.axis("off")
    plt.show()

# %%
for file in [dark_frame, sun_171, sun_195, sunpy_map]:
    plot_fits(file)
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 1024
# NAXIS2  =                 1024
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 1024
# NAXIS2  =                 1024
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 1024
# NAXIS2  =                 1024
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 4096
# NAXIS2  =                 4096
# ...

# %%
with fits.open("../data/01_raw/sunpy_map.fits") as hdul:
    hdul.info()
    primary_hdu = hdul[1]
    data = primary_hdu.data
# Out:
# Filename: ../data/01_raw/sunpy_map.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1  COMPRESSED_IMAGE    1 CompImageHDU    100   (4096, 4096)   int16
